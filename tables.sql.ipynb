# %%
# %load_ext sql

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine, Column, Integer, String
import psycopg2

# %%
# %%sql
# postgresql://postgres:puckDYNASTY14@localhost/mlb_etl

# %%
engine = create_engine('postgresql://postgres:puckDYNASTY14@localhost/mlb_etl')

# %%
# %%sql
# CREATE TABLE franchises (
# franchID VARCHAR,
# franchName VARCHAR,
# active VARCHAR,
# NAssoc VARCHAR,
# PRIMARY KEY (franchID));
# COPY franchises (franchID, franchName, active, NAssoc) FROM 'C:\Users\Public\Resources\TeamsFranchises.csv' DELIMITER ',' CSV HEADER;
# Out:
#  * postgresql://postgres:***@localhost/mlb_etl
# (psycopg2.errors.DuplicateTable) relation "franchises" already exists
#
# [SQL: CREATE TABLE franchises (
# franchID VARCHAR,
# franchName VARCHAR,
# active VARCHAR,
# NAssoc VARCHAR,
# PRIMARY KEY (franchID));]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
# %%sql
# SELECT * FROM franchises;
# Out:
#  * postgresql://postgres:***@localhost/mlb_etl
# 120 rows affected.
# [('ALT', 'Altoona Mountain City', 'N', None),
#  ('ANA', 'Los Angeles Angels of Anaheim', 'Y', None),
#  ('ARI', 'Arizona Diamondbacks', 'Y', None),
#  ('ATH', 'Philadelphia Athletics', 'N', 'PNA'),
#  ('ATL', 'Atlanta Braves', 'Y', 'BNA'),
#  ('BAL', 'Baltimore Orioles', 'Y', None),
#  ('BFB', 'Buffalo Bisons', 'N', None),
#  ('BFL', 'Buffalo Bisons', 'N', None),
#  ('BLC', 'Baltimore Canaries', 'NA', None),
#  ('BLO', 'Baltimore Orioles', 'N', None),
#  ('BLT', 'Baltimore Terrapins', 'N', None),
#  ('BLU', 'Baltimore Monumentals', 'N', None),
#  ('BNA', 'Boston Red Stockings', 'NA', 'ATL'),
#  ('BOS', 'Boston Red Sox', 'Y', None),
#  ('BRA', 'Brooklyn Atlantics', 'NA', None),
#  ('BRD', 'Boston Reds', 'N', None),
#  ('BRG', 'Brooklyn Gladiators', 'N', None),
#  ('BRS', 'Boston Reds', 'N', None),
#  ('BTT', 'Brooklyn Tip-Tops', 'N', None),
#  ('BUF', 'Buffalo Bisons', 'N', None),
# ...

# %%
# %%sql
# DROP TABLE salaries;
# CREATE TABLE salaries (
# yearID INT,
# teamID VARCHAR,
# IgID VARCHAR,
# playerID VARCHAR,
# salary INT);
# COPY salaries FROM 'C:\Users\Public\Resources\Salaries.csv' DELIMITER ',' CSV HEADER;
# Out:
#  * postgresql://postgres:***@localhost/mlb_etl
# Done.
# Done.
# 25575 rows affected.
# []

# %%
# %%sql
# DROP TABLE batting;
# CREATE TABLE  batting (
# playerID VARCHAR,
# yearID INT,
# stint INT,
# teamID VARCHAR,
# IgID VARCHAR,
# G INT,
# AB INT,
# R INT,
# H INT,
# Doubles INT,
# Triples INT,
# HR INT,
# RBI INT,
# SB INT,
# CS INT,
# BB INT,
# SO INT,
# IBB INT,
# HBP INT,
# SH INT,
# SF INT,
# GIDP INT
# );
# COPY batting FROM 'C:\Users\Public\Resources\Batting.csv' DELIMITER ',' CSV HEADER;
# Out:
#  * postgresql://postgres:***@localhost/mlb_etl
# Done.
# Done.
# 101332 rows affected.
# []

# %%
# %%sql
# DROP TABLE new_mlb;
# CREATE TABLE  new_mlb (
# playerID VARCHAR,
# nameFirst VARCHAR,
# nameLast VARCHAR,
# salary INT,
# yearID INT,
# teamID VARCHAR,
# IgID VARCHAR,
# divID VARCHAR,
# W INT,
# L INT,
# name VARCHAR
# );
# COPY new_mlb FROM 'C:\Users\Public\Resources\New_MLB.csv' DELIMITER ',' CSV HEADER;
# Out:
#  * postgresql://postgres:***@localhost/mlb_etl
# Done.
# Done.
# 204008 rows affected.
# []
